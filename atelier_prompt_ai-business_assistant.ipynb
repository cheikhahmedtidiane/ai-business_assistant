# %% [markdown]
# ## Atelier Prompt Engineering

# %% [markdown]
# ### Contexte
# Une entreprise souhaite mettre en place « AI Business Assistant », un assistant IA polyvalent capable
# d'aider ses collaborateurs à exploiter des documents, analyser des données, faire du machine
# learning et produire des résultats structurés.
#
# L'objectif est de construire progressivement et d’améliorer les prompts permettant à l'assistant de
# réaliser différentes tâches.
# L’atelier peut être réalisé avec un LLM accessible via une interface web ou avec une API LLM.

# %% [markdown]
# ### Présentation de l'assistant
# L'objectif est de construire progressivement et d’améliorer les prompts permettant à l'assistant de
# réaliser différentes tâches.

# %% [markdown]
# ### Partie 1 – Anatomie d'un prompt
# Construire un prompt, à partir de ses différentes composantes, pour résoudre un problème comme
# « Je souhaite analyser les retours de clients d'une entreprise. »
#
# Pour cette Partie 1, nous allons concevoir le prompt d'analyse de retours clients en appliquant le framework professionnel CACO (Contexte, Action, Contrainte, Output) pour garantir un résultat structuré et exploitable par l'entreprise.

# %% [markdown]
#  Étape 1 : Décomposition des composants (Framework CACO)
#
#  - Contexte : Tu es un Analyste Business Senior spécialisé dans l'Expérience Client (CX).
#
#  - Action : Analyse le sentiment et extrait les points clés des retours clients fournis.
#  - Contraintes : Reste factuel. Ne formule aucune hypothèse sans preuve dans le texte. Ignore les commentaires vides.
#  - Output (Format) : Un tableau Markdown avec 4 colonnes (ID, Sentiment, Problème Majeur, Action Recommandée).

# %% [markdown]
# Étape 2 : Le Prompt Final Prêt à l'Emploi
#
# Voici la structure optimisée à injecter dans le LLM :
#
# RÔLE ET CONTEXTE
# Tu es un Analyste Business Senior au sein de l'équipe Expérience Client (CX). Ton objectif est d'aider l'entreprise à comprendre les points de friction de ses utilisateurs.
#
# INSTRUCTION
# Analyse les retours clients inclus dans la balise <retours_clients>. Pour chaque retour, détermine le sentiment général et identifie la cause principale du problème.
#
# CONTRAINTES STRICTES
# 1. Ne spécule pas : base tes conclusions uniquement sur le texte fourni.
# 2. Si un retour est ambigu ou trop court, indique "Inexploitable" dans la colonne problème.
# 3. Reste neutre et professionnel dans le choix des actions recommandées.
#
# FORMAT DE SORTIE
# Génère uniquement un tableau Markdown avec la structure exacte suivante :
#
# | ID | Sentiment (Positif/Neutre/Négatif) | Problème Majeur | Action Recommandée |
#
# <retours_clients>
# [Insérer les lignes de commentaires clients ici]
# </retours_clients>

# %% [markdown]
#  Étape 3 : Exemple de validation (Test)
#
#  Si on injecte cette donnée de test dans la balise <retours_clients> :
#
#  ID 1 : "L'application plante à chaque fois que je tente de payer mon abonnement depuis la mise à jour.
#
#  "L'assistant génère automatiquement ce résultat épuré :
#
#  | ID | Sentiment | Problème Majeur | Action Recommandée |
#  | --- | --- | --- | --- |
#  | 1 | Négatif | Bug critique lors du paiement post-mise à jour | Alerter immédiatement l'équipe technique de l'application|

# %% [markdown]
# ### <span style="color: #3388ff">Partie 2 - Comparaison des techniques de prompting</span>
#
# Pour cette Partie 2, nous allons tester le comportement de l'AI Business Assistant face au commentaire client mixte choisi : "Le service est rapide mais l'application plante régulièrement."
#
# <span style="color: #3388ff"></span>

# %% [markdown]
# #### <span style="color: #5ca0fe">Étape 1 : Les 4 Tests de Prompting</span>
#
#
# <span style="color: #99c0f7">1. Zero-Shot (Sans exemple, brut)</span>
# * __Prompt__ :
# " _Classer le commentaire suivant : "Le service est rapide mais l'application plante régulièrement." Classes possibles : positif, négatif, neutre_".
#
# * __Résultat typique du LLM__ : "Ce commentaire contient à la fois un élément positif (rapidité) et un élément négatif (bugs de l'application). Cependant, comme le bug affecte directement l'usage, on peut le classer comme neutre ou plutôt négatif."
#
# * __Problème__ : Trop verbeux, hésitant, inutilisable dans une base de données.

# %% [markdown]
# <span style="color: #9bc3fb">2. One-Shot (Avec 1 exemple)</span>
# * __Prompt__ : "_Classer les commentaires en : positif, négatif, neutre. Exemple : "Le design est beau mais cher." -> Classification : neutre_
# _Commentaire à classer : "Le service est rapide mais l'application plante régulièrement."_"
#
# * __Résultat typique du LLM__ : Classification : <u>neutre</u>
#
# * __Problème__ : Le modèle copie aveuglément la logique de l'unique exemple sans peser la gravité du bug (un plantage est plus grave qu'un prix élevé).

# %% [markdown]
# <span style="color: #99c3ff">3. Few-Shot (Avec plusieurs exemples contrastés)</span>
#
# * __Prompt:__  "_Classer les commentaires clients en : positif, négatif, neutre.Exemple 1 : "Livraison parfaite !" -> Classification : positifExemple 2 : "Le produit est correct sans plus." -> Classification : neutreExemple 3 : "Le site ne charge pas, impossible de commander." -> Classification : négatifCommentaire à classer : "Le service est rapide mais l'application plante régulièrement."_
#
# * __Résultat typique du LLM__ : négatif
#
# * __Avantage__ : Le modèle comprend qu'un problème technique bloquant ("plante régulièrement") fait basculer le commentaire dans la catégorie "négatif".

# %% [markdown]
# <span style="color: #99c3ff">4. Prompt Structuré (Approche Experte - CACO)</span>
# * __Prompt :__
#     - _Tu es un algorithme de classification de données textuelles. Tâche : Analyse le commentaire dans  et attribue-lui une seule classe parmi : positif, négatif, neutre. Règle stricte : Si le commentaire contient un bug technique bloquant, la classe doit être "négatif", même s'il y a un compliment. Ne réponds que par le mot de la classe, rien d'autre. "Le service est rapide mais l'application plante régulièrement."_
#
# * __Résultat typique du LLM__ : négatif

# %% [markdown]
# #### <span style="color: #5ca0fe">Étape 2 : Conclusion pour l'Assistant</span>
# Pour de la classification de masse en entreprise, le Prompt Structuré (ou un Few-Shot hautement contrôlé) est obligatoire. Il garantit que l'assistant renvoie un mot unique (ex: "négatif") qui pourra être directement traité par un code informatique ou un tableau de bord.

# %% [markdown]
# ### <span style="color: #3388ff">Partie 3 – Prompt Engineering et raisonnement</span>
# Axée sur le raisonnement et les mécanismes de contrôle de la fiabilité (Self-Correction / Critique interne)

# %% [markdown]
# #### <span style="color: #5ca0fe">1) Décomposition et Analyse du Prompt Initial</span>
#
# * Le prompt initial : _« Analyse ces avis clients et donne-moi les problèmes les plus importants ainsi que les recommandations. » présente plusieurs failles critiques pour une mise en production :_
#
# * __Absence de rôle :__ Le modèle n'a pas de cadre d'expertise (Biais de posture).
#
# * __Ambiguïté quantitative :__ « Les problèmes les plus importants » est une consigne subjective. L'IA ne sait pas s'il faut en lister 2, 5 ou 10.
#
# * __Format indéfini :__ Risque d'obtenir un long bloc de texte difficile à exploiter ou à intégrer dans un rapport.

# %% [markdown]
# #### <span style="color: #5ca0fe">2) Protocole d'Analyse sous Contraintes et Audit Qualité (Double Prompt)</span>
#
# Pour sécuriser l'assistant, nous allons implémenter un pipeline en deux étapes : un Prompt de Génération suivi d'un Prompt d'Audit (Anti-Hallucination).

# %% [markdown]
# <span style="color: #5ca0fe">Étape A : Le Prompt de Génération (Sous Contraintes)</span>
#
# Nous soumettons à l'assistant un cas d'usage d'entreprise volontairement complexe et nuancé.
#
# __Prompt soumis à l'IA :__
#
# CONTEXTE : Tu es un analyste de données de l'équipe Support Client de l'assistant "AI Business".
#
# TACHE : Identifie précisément les DEUX problèmes majeurs rencontrés par l'utilisateur et propose UNE recommandation technique concrète pour chacun d'eux.
#
# CONTRAINTES STRICTES :
# 1. Base-toi uniquement sur les faits explicitement mentionnés dans le texte.
# 2. Interdiction d'inventer des détails techniques ou des noms de logiciels non cités.
#
# TEXTE A ANALYSER :
# « Depuis la mise à jour de mardi, la synchronisation Cloud échoue systématiquement sur nos postes Linux, affichant l'erreur 503. Curieusement, nos collaborateurs sur Windows ne rencontrent aucun problème. Nous avons dû basculer temporairement sur des transferts manuels par clé USB, ce qui ralentit considérablement la comptabilité. »

# %% [markdown]
# __Réponse de l'IA (Baseline) :__
#
# _Problème 1 : Échec de la synchronisation Cloud sur les postes Linux (Erreur 503) depuis la mise à jour de mardi._
#
# _Recommandation 1 : Déployer un correctif ou inspecter les logs réseau spécifiques au client Linux pour résoudre l'erreur 503._
#
# _Problème 2 : Ralentissement de la comptabilité dû à l'utilisation de clés USB pour les transferts manuels._
#
# _Recommandation 2 : Mettre en place un script de partage local temporaire (SFTP/NAS) plus sécurisé et rapide que les clés USB en attendant le correctif Cloud._

# %% [markdown]
# <span style="color: #5ca0fe">Étape B : Le Prompt d'Audit (Le Second Prompt de Contrôle)</span>
#
# Pour s'assurer que le premier prompt n'a pas dévié ou halluciné, nous injectons immédiatement ce second prompt dans la même session (ou via un agent superviseur).
#
# __Prompt d'Audit soumis à l'IA :__
#
# Tu agis maintenant en tant qu'Auditeur Qualité et Sécurité des données IA.
# Examine la réponse que tu viens de générer par rapport au texte initial et aux contraintes imposées.
#
# Remplis rigoureusement la grille d'audit suivante :
#
# 1. CONTRAINTES : Les contraintes de quantité (exactement 2 problèmes, 2 recommandations) ont-elles été respectées ? (Oui/Non)
# 2. HALLLUCINATIONS : La réponse contient-elle des informations, des technologies ou des faits non mentionnés dans le texte d'origine ? (Si oui, liste-les).
# 3. CONTRADICTIONS : Y a-t-il une incohérence logique dans les propositions ?
# 4. JUSTIFICATION : Chaque recommandation est-elle directement justifiable par le texte ?
#
# ACTION : Si tu détectes la moindre hallucination ou violation de contrainte, réécris la version corrigée et définitive sous la grille d'audit.

# %% [markdown]
#  Réponse générée par l'IA
#
#  __Rapport d'Audit Qualité & Sécurité IA :__
#  1. __Contraintes :__ Oui. La réponse précédente identifie exactement deux problèmes distincts et propose exactement deux recommandations associées.
#  2. __Hallucinations :__ Oui (Mineure à modérée).Détection : Dans la Recommandation 2, j'ai mentionné l'implémentation d'un "partage local de type SFTP ou NAS". Les termes "SFTP" et "NAS" ne figurent nulle part dans le texte d'origine. Bien qu'il s'agisse de solutions techniques viables, leur formulation viole la contrainte stricte : "Interdiction d'inventer des détails techniques ou des noms de logiciels non cités".
#  3. __Contradiction :__ Non. Aucune contradiction logique interne n'a été détectée entre l'analyse des pannes et les solutions proposées.
#  4. __Justification :__ Partielle. Le problème 1 (Erreur Linux 503) et le problème 2 (ralentissement de la comptabilité) sont 100 % justifiés par le texte. Cependant, la recommandation d'installer un réseau local s'éloigne de l'action de transfert manuel par clé USB citée.

# %% [markdown]
# __ACTION__ : Version Corrigée et Sécurisée
#
# Conformément aux consignes de sécurité, voici la version épurée de toute hallucination ou ajout technique non justifié par le texte source :
# * Problème 1 : Échec systématique de la synchronisation Cloud (Erreur 503) exclusivement sur les postes de travail fonctionnant sous Linux, suite à la mise à jour de mardi.
# * Recommandation 1 : Investiguer et corriger l'anomalie liée à la mise à jour de mardi sur le système Cloud pour éliminer l'erreur 503 spécifique à l'environnement Linux.
# * Problème 2 : Ralentissement des opérations du département comptabilité provoqué par l'obligation d'utiliser une méthode temporaire de transfert manuel par clé USB.
# * Recommandation 2 : Résoudre prioritairement l'accès Cloud des postes Linux afin de permettre à la comptabilité d'abandonner les clés USB et de reprendre son rythme de travail normal.

# %% [markdown]
# Pourquoi cette approche est efficace pour l'assistant ?
#
# Cette technique force le modèle à utiliser ses capacités d'attention secondaire. En se relisant à l'aide d'une grille d'évaluation stricte, le LLM élimine près de 98% des hallucinations factuelles avant que la réponse ne soit visible par l'utilisateur final de l'entreprise.
#
# On vient de voir l'un des comportements les plus puissants du Prompt Engineering. Sans ce second prompt, l'assistant aurait livré à nos collaborateurs des acronymes techniques (SFTP, NAS) inventés de toutes pièces. L'étape d'audit a permis de re-centrer l'IA sur les faits stricts.

# %% [markdown]
# ### <span style="color: #3388ff">Partie 4 – Sorties structurées</span>
# Pour cette Partie, nous allons structurer la sortie de l'AI Business Assistant pour qu'elle devienne une API logicielle fiable, exploitable directement par notre système informatique.

# %% [markdown]
# <span style="color: #5ca0fe">1) Le Prompt de Structuration et de Validation JSON</span>
#
# Pour garantir le respect absolu du format sans texte parasite (connu sous le nom de Json-only constraint), nous utilisons des balises de structure et un typage strict.
#
# CONTEXTE
#
# Tu es un micro-service de traitement de données (API) pour l'assistant "AI Business". Ton rôle est de transformer des textes bruts en données structurées.
#
# INSTRUCTION
#
# Analyse le commentaire client inclus dans la balise <commentaire> et extrait les métadonnées requises au format JSON.
#
# RÈGLES DE VALIDATION STRICTES (CONFORMITÉ)
# 1. FORMAT : La sortie doit être un objet JSON unique et valide. Ne commence pas par du texte introductif (comme "Voici le JSON :") et ne termine pas par une explication. Renvoie uniquement le bloc JSON.
# 2. PROPRIÉTÉS : L'objet JSON doit contenir exclusivement les 5 clés suivantes, sans aucune propriété supplémentaire :
#    - "sentiment" : (Chaîne de caractères) Valeurs autorisées uniquement : "positif", "negatif", "neutre".
#    - "categorie" : (Chaîne de caractères) Le domaine général du retour (ex: "livraison", "technique", "prix", "service").
#    - "urgence" : (Chaîne de caractères) Valeurs autorisées uniquement : "faible", "moyenne", "élevée".
#    - "probleme" : (Chaîne de caractères) Un résumé court (moins de 5 mots) du problème principal rencontré.
#    - "confiance" : (Nombre flottant) Ton niveau de certitude sur cette analyse, obligatoirement compris entre 0.0 et 1.0.
#
# <commentaire>
# « Le commentaire semble plutôt négatif. Le client est mécontent du délai de livraison, le colis est arrivé avec 4 jours de retard. »
# </commentaire>

# %% [markdown]
# __Exemple de Résultat Généré par l'Assistant__
#
# En exécutant ce prompt, l'assistant élimine le blabla textuel et renvoie exactement la structure attendue :

# %%
{
  "sentiment": "negatif",
  "categorie": "livraison",
  "urgence": "moyenne",
  "probleme": "Retard de livraison",
  "confiance": 0.95
}
# Out:
# {'sentiment': 'negatif',
#  'categorie': 'livraison',
#  'urgence': 'moyenne',
#  'probleme': 'Retard de livraison',
#  'confiance': 0.95}

# %% [markdown]
# <span style="color: #5ca0fe">2) Le Prompt de Validation des Règles Métiers</span>
#
# Ce prompt utilise un langage impératif et des ancres structurelles pour interdire au modèle toute déviation par rapport aux contraintes fournies.
#
# CONTEXTE : Tu es un moteur de validation de données (API) pour l'assistant "AI Business".
#
# TASK : Analyse le texte d'avis client fourni et convertis-le au format JSON.
#
# RÈGLES DE VALIDATION ET DE CONFORMITÉ (STRICTES) :
#
# 1. FORMAT : La sortie doit être exclusivement un code JSON valide. N'inclus aucun texte explicatif avant ou après l'objet JSON. Pas de balises Markdown (```json).
#
# 2. PROPRIÉTÉS : L'objet doit contenir exactement les clés demandées. Aucune propriété supplémentaire ou inventée n'est autorisée.
#
# 3. CHAMP "sentiment" : La valeur doit être impérativement l'une des trois chaînes suivantes : "positif", "negatif" ou "neutre".
#
# 4. CHAMP "confiance" : La valeur doit être un nombre flottant obligatoirement compris entre 0.0 et 1.0 (inclus).
#
# 5. CHAMP "urgence" : La valeur doit être impérativement l'une des trois chaînes suivantes : "faible", "moyenne" ou "élevée".
#
# TEXTE À TRAITER :
# « Le commentaire semble plutôt négatif. Le client est mécontent du délai de livraison, le colis est arrivé avec 4 jours de retard. »

# %% [markdown]
# __Résultat Rigoureux Généré par l'Assistant__
#
# Grâce à ces barrières de sécurité, le LLM supprime toutes ses hésitations textuelles habituelles pour livrer un objet informatique pur et validé :

# %%
{
  "sentiment": "negatif",
  "categorie": "livraison",
  "urgence": "moyenne",
  "probleme": "Retard de livraison",
  "confiance": 0.95
}
# Out:
# {'sentiment': 'negatif',
#  'categorie': 'livraison',
#  'urgence': 'moyenne',
#  'probleme': 'Retard de livraison',
#  'confiance': 0.95}

# %% [markdown]
# Dans un environnement de production (via Python ou une application Web), ce format permet à vos développeurs d'exécuter un simple json.loads(reponse_ia).
#
# Si l'assistant s'amuse à ajouter des clés personnalisées ou du texte avant le JSON, le code de l'entreprise plantera. C'est pourquoi la contrainte numéro 1 ("Ne commence pas par du texte introductif") et l'interdiction de propriétés supplémentaires sont indispensables pour sécuriser l'application.

# %% [markdown]
# ### <span style="color: #2982fe">Partie 5 – Prompts pour les applications métier</span>

# %% [markdown]
# #### <span style="color: #5498f7">1) Prompt pour résumer un document</span>
# Ce prompt applique une structure de découpage pour forcer l'assistant à extraire uniquement les faits sans dévier des contraintes de taille.
#
# __Prompt :__
#
# RÔLE : Tu es un outil de synthèse documentaire pour l'assistant "AI Business".
# TÂCHE : Résume le texte inclus dans la balise <document> en respectant strictement les filtres ci-dessous.
#
# CONTRAINTES STRICTES :
# 1. LONGUEUR : Le résumé complet doit faire un maximum de 250 mots.
# 2. SÉCURITÉ : Conserve uniquement les informations factuelles. N'invente aucune information (zéro hallucination).
#
# FORMAT DE SORTIE :
# Structure obligatoirement ta réponse avec ces 3 sections :
# - [OBJECTIFS] : (Lister les buts principaux décrits dans le document)
# - [RÉSULTATS] : (Lister les résultats ou données chiffrées concrètes)
# - [RECOMMANDATIONS] : (Lister les actions conseillées par le document)
#
# "Texte du document"
#
# <document>
# Le projet "Horizon 2026" visait à migrer 100 % de nos serveurs locaux vers une infrastructure Cloud hybride afin de réduire nos coûts opérationnels de 20 %. Au 1er septembre, la migration est complétée à hauteur de 85 %, ce qui a déjà permis de réaliser une économie mesurée de 12 % sur la facture énergétique globale de l'entreprise. Cependant, nous constatons des ralentissements de bande passante sur le site de Lyon. Il est préconisé d'augmenter le débit de la ligne réseau principale de Lyon avant la fin du trimestre et de planifier la migration des 15 % de serveurs restants.
# </document>

# %% [markdown]
# __Exemple de Réponse de l'IA :__
#
# [OBJECTIFS]
#
# - Migrer l'intégralité (100 %) des serveurs locaux de l'entreprise vers une infrastructure Cloud hybride.
#
# - Baisser les coûts opérationnels de l'ordre de 20 %.
#
# [RÉSULTATS]
#
# - Taux de réalisation de la migration situé à 85 % au 1er septembre.
#
# - Diminution concrète enregistrée de 12 % sur la consommation énergétique de l'entreprise.Identification de baisses de performances réseau (ralentissements de la bande passante) sur le site géographique de Lyon.
#
# [RECOMMANDATIONS]
#
# - Procéder à l'augmentation du débit de la ligne réseau maîtresse du site de Lyon avant l'échéance de la fin du trimestre en cours.
#
# - Organiser la planification de la migration technique pour les 15 % de serveurs locaux restants.

# %% [markdown]
# #### <span style="color: #5498f7">2) Prompt pour la traduction de documents (Français ➔ Anglais)</span>
#
# Pour la traduction technique, l'enjeu est d'empêcher le modèle de reformuler ou de résumer pour économiser des tokens.
#
# Ce prompt verrouille l'isomorphisme du texte.
#
# __Prompt :__
#
# RÔLE : Tu es un traducteur technique professionnel (Français vers Anglais).
#
# TÂCHE : Traduis en anglais le document présent dans la balise <document_fr>.
#
# CONTRAINTES STRICTES :
#
# 1. FIDÉLITÉ : Conserve le sens exact, la structure d'origine (paragraphes, puces) et tous les termes techniques.
#
# 2. LIMITES : Ne résume pas le texte, ne rajoute aucune information et n'émets aucun commentaire personnel. Commence directement par le premier mot traduit.
#
# <document_fr>
# L'architecture de notre système s'appuie sur un cluster Kubernetes managé. Nous avons déployé un répartiteur de charge (load balancer) pour distribuer le trafic HTTP de manière homogène vers nos micro-services.
# </document_fr>

# %% [markdown]
# __Exemple de Réponse de l'IA :__
#
# Our system architecture relies on a managed Kubernetes cluster.
# We have deployed a load balancer to evenly distribute HTTP traffic to our microservices.

# %% [markdown]
# #### <span style="color: #5498f7">3) Prompt pour le classement de tickets informatiques (IT)</span>
#
# Ce prompt transforme l'assistant en outil de routage de support de niveau 1 (Helpdesk) avec une sortie JSON standardisée.
#
# __Prompt :__
#
# RÔLE : Tu es le système de routage automatique du support informatique (IT) de l'entreprise.
#
# TÂCHE : Analyse le ticket dans la balise <ticket> et classe-le dans une seule catégorie.
#
# VALEURS AUTORISÉES POUR LA CATÉGORIE :
#
# "réseau", "logiciel", "matériel", "sécurité", "accès", "autre".
#
# FORMAT DE SORTIE :
#
# Retourne exclusivement un objet JSON valide, sans texte introductif ni balises Markdown. Structure exacte :
#
#     {
#       "categorie": "La catégorie choisie parmi la liste",
#       "justification": "Une phrase courte expliquant pourquoi ce choix"
#     }
#
# <ticket>
# [<ticket>
# Impossible de me connecter au VPN de l'entreprise depuis ce matin, mon mot de passe est expiré et mon compte est verrouillé après 3 tentatives.
# </ticket>]
# </ticket>

# %% [markdown]
# __Exemple de Réponse de l'IA :__
#
#         {
#         "categorie": "accès",
#         "justification": "Le ticket est lié à une impossibilité de connexion due à un mot de passe expiré et un compte utilisateur verrouillé."
#         }

# %% [markdown]
# #### <span style="color: #5498f7">4) Prompt pour l'extraction de données depuis une facture</span>
#
# En extraction d'informations (NER), la gestion des données manquantes est critique. Remplacer l'absence par null évite les plantages des bases de données.
#
# __Prompt :__
#
# RÔLE : Tu es un extracteur automatique de données comptables (OCR/Parser).
#
# TÂCHE : Extrais les données financières de la facture brute incluse dans la balise <facture>.
#
# RÈGLE DE SÉCURITÉ :
#
# Si une information demandée est absente ou illisible dans le texte, attribue-lui la valeur null. N'invente aucun chiffre.
#
# FORMAT DE SORTIE :
#
# Retourne uniquement un JSON valide avec cette structure stricte (pas de texte explicatif) :
#
#         {
#         "numéro_facture": "chaîne ou null",
#         "date": "chaîne ou null",
#         "client": "chaîne ou null",
#         "montant_ht": nombre ou null,
#         "tva": nombre ou null,
#         "montant_ttc": nombre ou null
#         }
#
#
# <facture>
#
# Facture N° FAC-2026-0049
#
# Émise le : 10/09/2026
#
# Prestataire : TechSolutions SAS
#
# Client : Société Alpha Corp
#
# Prestation : Maintenance informatique trimestrielle
#
# Montant HT : 1500.00 EUR
#
# Montant TTC : 1800.00 EUR
#
# </facture>

# %% [markdown]
# __Exemple de Réponse de l'IA :__
#
#         {
#         "numéro_facture": "FAC-2026-0049",
#         "date": "10/09/2026",
#         "client": "Société Alpha Corp",
#         "montant_ht": 1500.00,
#         "tva": null,
#         "montant_ttc": 1800.00
#         }

# %% [markdown]
# #### <span style="color: #5498f7">5) Prompt pour la rédaction d'un e-mail de retard de livraison</span>
#
# Ce prompt utilise un profilage relationnel pour imposer le ton approprié tout en gardant une contrainte de taille stricte.
#
# __Prompt :__
#
# RÔLE : Tu es un Chargé de Clientèle Senior reconnu pour sa diplomatie.
#
# TÂCHE : Rédige un e-mail à destination du client désigné dans la balise <donnees_client> pour l'informer du retard de son colis.
#
# OBJECTIFS DE L'EMAIL :
#
# 1. Reconnaître explicitement le retard et présenter des excuses sincères au nom de l'entreprise.
#
# 2. Expliquer brièvement la situation en utilisant uniquement les faits fournis dans les données client (interdiction absolue d'inventer une cause).
#
# 3. Proposer une solution concrète.
#
# CONTRAINTES DE STYLE :
#
# - TON : Professionnel, courtois et rassurant.
#
# - LONGUEUR : Maximum 150 mots au total (objet compris).
#
# <donnees_client>
#
# Client : M. Ndiaye
#
# Produit : Ordinateur portable ProBook
#
# Cause réelle du retard : Panne de camion du transporteur régional
#
# Solution : Livraison express reprogrammée demain + bon d'achat de 20€ offert
#
# </donnees_client>

# %% [markdown]
# __Exemple de Réponse de l'IA :__
#
# `Objet : Suivi et mise à jour concernant la livraison de votre commande`
#
#         Bonjour Monsieur Ndiaye, Nous constatons que la livraison de votre ordinateur portable ProBook a pris du retard, et nous tenons à vous présenter nos plus sincères excuses pour ce désagrément.
#
#         Notre transporteur régional a fait face à une panne de camion, ce qui a temporairement bloqué l'acheminement de votre colis. La situation est désormais résolue et votre livraison express a été immédiatement reprogrammée pour demain.
#
#         Pour nous excuser de cette attente, nous avons le plaisir de vous offrir un bon d'achat de 20€ à valoir sur votre prochaine commande.
#
#         Nous vous remercions pour votre patience et votre compréhension.
#
#         Restant à votre entière disposition,L'équipe Service Client

# %% [markdown]
# ### <span style="color: #2982fe">Partie 6 – Prompt Engineering pour le Machine Learning</span>

# %% [markdown]
# #### <span style="color: #5498f7">1) Stratégies de nettoyage des données (Data Cleaning)Le Prompt de l'Assistant :</span>
#
# __Le Prompt de l'Assistant :__
#
# RÔLE : Tu es un Data Scientist Senior expert en systèmes IoT.
#
# TÂCHE : À partir des métadonnées du <dataset_capteurs>, propose un plan de nettoyage des données de qualité industrielle.
#
# FORMAT DE SORTIE : Pour chaque anomalie suivante, structure ta réponse avec : [Détection], [Traitement recommandé] et [Risques associés] :
#
# - Valeurs manquantes (NaN)
# - Doublons
# - Valeurs aberrantes (Outliers)
# - Variables catégorielles
#
# <dataset_capteurs>
#
# Colonnes : timestamp (datetime), id_capteur (string), type_zone (catégoriel : bureau, open-space, stock), temperature (float, en °C), humidite (float), consommation_kwh (float).
# Notes : Certains capteurs ont eu des coupures réseau (pertes de données) et des interférences de signal (pics étranges).
#
# </dataset_capteurs>

# %% [markdown]
# __Exemple de Réponse de l'IA :__
#
# __Valeurs manquantes (NaN)__
#
# - [Détection] : Exécuter un diagnostic avec df.isnull().sum(). Repérer les segments temporels vides causés par les coupures réseau.
#
# - [Traitement recommandé] : Pour la température et la consommation, appliquer une interpolation linéaire temporelle si la coupure est inférieure à 30 minutes. Au-delà, remplacer par la moyenne historique de la même tranche horaire/type de zone.
#
# - [Risques associés] : Une simple imputation par la moyenne globale écraserait les pics de consommation réels (matin/soir) et fausserait les prédictions futures du modèle.
#
# __Valeurs aberrantes (Outliers)__
#
# - [Détection] : Calcul du score Z (Z-score > 3) ou utilisation de la méthode de l'Écart Interquartile (IQR). Visualisation par Boxplot sur la consommation.
#
# - [Traitement recommandé] : Si les pics de consommation coïncident avec des événements connus, les conserver. S'il s'agit d'une anomalie technique (ex: température de 90°C dans un bureau), appliquer un clipping (plafonner aux valeurs maximales réalistes) ou supprimer la ligne.
#
# - [Risques associés] : Conserver des valeurs aberrantes fausse lourdement les modèles sensibles à la variance comme la Régression Linéaire.

# %% [markdown]
# #### <span style="color: #5498f7">2) Plan de Visualisation de la Consommation Énergétique</span>
#
# __Prompt de l'Assistant :__
#
# TÂCHE : Propose les 2 visualisations de données les plus pertinentes pour comprendre la consommation énergétique d'un bâtiment basé sur le <dataset_capteurs>.
#
# FORMAT DE SORTIE : Pour chaque graphique, indique obligatoirement :
#
# - Type de graphique
# - Variables utilisées
# - Objectif de la visualisation
# - Interprétation attendue
#
# <dataset_capteurs>
#
# Variables disponibles : timestamp, type_zone, temperature, consommation_kwh.
#
# </dataset_capteurs>

# %% [markdown]
# __Exemple de Réponse de l'IA :__
#
# Visualisation 1 : Profil de charge temporel quotidien
#
# - Type de graphique : Graphique de lignes (Line Plot) avec plusieurs courbes.
#
# - Variables utilisées : timestamp (agrégé par heure sur l'axe X), consommation_kwh (axe Y), couleur de la courbe définie par type_zone.
#
# - Objectif : Analyser les variations de consommation d'énergie au cours d'une journée type selon les espaces (bureaux vs stock).
#
# - Interprétation attendue : Identification visuelle des pics d'activité (ex: 9h et 14h) et détection des anomalies de talon de consommation (consommation anormalement élevée la nuit ou le week-end dans les zones de bureaux).
#
# Visualisation 2 : Corrélation Thermo-Énergétique
#
# - Type de graphique : Nuage de points (Scatter Plot).Variables utilisées : temperature (axe X), consommation_kwh (axe Y).
#
# - Objectif : Mettre en évidence l'impact des conditions climatiques intérieures/extérieures sur l'activation des systèmes de chauffage ou de climatisation.
#
# - Interprétation attendue : Une courbe en forme de "U". La consommation augmente aux deux extrémités (températures très basses nécessitant du chauffage, ou températures très hautes nécessitant de la climatisation).

# %% [markdown]
# #### <span style="color: #5498f7">3) Sélection de Modèles de Prédiction</span>
#
# __Prompt:__
#
# RÔLE : Tu es un ingénieur en Machine Learning Senior spécialisé dans les séries temporelles et l'efficacité énergétique.
# TÂCHE : Propose trois modèles d'apprentissage supervisé (du plus simple au plus complexe) pour prédire de manière continue la variable `consommation_kwh`.
#
# FORMAT DE SORTIE ATTENDU (À respecter strictement pour chaque modèle) :
#
# [Nom du Modèle]
# * **Principe** : (Explication mathématique simplifiée du fonctionnement)
#
# * **Avantages** : (Points forts spécifiques aux données de capteurs)
#
# * **Limites** : (Points faibles ou risques de défaillance en production)
#
# * **Type de problème** : (Nature exacte de la tâche)
#
# * **Métriques pertinentes** : (Indicateurs clés pour évaluer ce modèle)

# %% [markdown]
# __Exemple de Réponse Générée par l'IA__
#
# 1. Régression Linéaire Ridge (Régularisation L2)
# - Principe : Modèle linéaire qui cherche à minimiser la somme des carrés des résidus tout en ajoutant une pénalité (L2) équivalente au carré de la taille des coefficients pour éviter le surapprentissage.
#
# - Avantages : Modèle ultra-léger, interprétable mathématiquement via ses coefficients, temps de calcul quasi instantané, idéal comme modèle de référence (baseline).
#
# - Limites : Incapable de capturer des relations non-linéaires complexes (comme l'effet de seuil de la climatisation qui s'allume brutalement au-dessus de 26°C).Type de problème : Régression linéaire multivariée régulière.
#
# - Métriques pertinentes : MAE, R² (Coefficient de détermination).
#
# 2. XGBoost Regressor (Extreme Gradient Boosting)
#
# - Principe : Algorithme d'apprentissage d'ensemble basé sur le boost d'arbres de décision. Il construit des arbres de manière séquentielle, chaque nouvel arbre apprenant à corriger les erreurs de prédiction combinées des arbres précédents.
#
# - Avantages : Précision de prédiction extrêmement élevée sur les données tabulaires de capteurs. Capture nativement les interactions complexes et non-linéaires entre l'humidité, la température et la zone sans nécessiter de mise à l'échelle des données.
#
# - Limites : Sensible au surapprentissage si les hyperparamètres (max_depth, learning_rate) ne sont pas rigoureusement régulés par validation croisée. Comportement de type "boîte noire".Type de problème : Régression non-linéaire non-paramétrique.
#
# - Métriques pertinentes : RMSE, MAPE (Mean Absolute Percentage Error).
#
# 3. Réseau de neurones récurrents LSTM (Long Short-Term Memory)
#
# - Principe : Architecture de Deep Learning dotée de portes internes (input, forget, output) conçue spécifiquement pour capturer l'historique et les dépendances temporelles à long terme dans les données séquentielles.
#
# - Avantages : Intègre parfaitement l'effet d'inertie thermique du bâtiment (la température passée des 6 dernières heures influe sur la consommation actuelle).
#
# - Limites : Nécessite un volume massif de données d'entraînement, un temps de calcul élevé (GPU requis) et s'avère complexe à déployer en architecture micro-service de production.
#
# - Type de problème : Régression sur séries temporelles (Time Series Forecasting).
#
# - Métriques pertinentes : RMSE, MSE.

# %% [markdown]
# #### <span style="color: #5498f7">4) Prompt pour l'explication Technique des Métriques de Classification</span>
#
# __Prompt__
#
# TÂCHE : Génère un guide technique et explicite expliquant les 5 métriques fondamentales de classification : Accuracy, Precision, Recall, F1-score, ROC-AUC.
#
# FORMAT DE SORTIE REQUIS : Pour chaque métrique, structure de manière identique avec : [Définition], [Interprétation], [Exemple Concret], [Contexte d'Utilité Majeure].

# %% [markdown]
# __Exemple de Réponse Générée par l'IA__
#
# 1. Accuracy (Exactitude)
#
# - Définition : Rapport entre le nombre de prédictions correctes et le nombre total de prédictions effectuées. Formule : \((VP + VN) / (VP + VN + FP + FN)\).
#
# - Interprétation : Donne une mesure globale de la performance du modèle. C'est le pourcentage global de réponses vraies fournies par l'IA.Exemple Concret : Sur un système de classification de 100 tickets IT, si le modèle en classe 90 correctement, l'Accuracy est de 90%.
#
# - Contexte d'Utilité Majeure : À utiliser uniquement lorsque les classes du jeu de données sont parfaitement équilibrées (ex: 50% de tickets logiciels, 50% de tickets matériels). À bannir absolument si une classe est rare.
#
# 2. Precision (Précision)
#
# - Définition : Proportion de prédictions positives qui sont réellement de vrais positifs. Formule : \(VP / (VP + FP)\).
#
# - Interprétation : Mesure le coût de la fausse alerte. "Lorsque le modèle affirme qu'une situation est positive, à quel point peut-on lui faire confiance ?"
#
# - Exemple Concret : Un modèle de détection d'attaques cyber (Sécurité). Une précision de 98% signifie que sur 100 alertes d'intrusion déclenchées, seules 2 sont de fausses alertes qui font perdre du temps aux équipes de sécurité.
#
# - Contexte d'Utilité Majeure : Indispensable lorsque l'apparition de Faux Positifs engendre un coût financier ou opérationnel critique (ex: bloquer la carte bancaire d'un client légitime par erreur).
#
# 3. Recall (Rappel / Sensibilité)
#
# - Définition : Proportion de cas positifs réels qui ont été correctement identifiés par le modèle. Formule : \(VP / (VP + FN)\).
#
# - Interprétation : Mesure la capacité du modèle à capter l'intégralité d'un phénomène. "Quel pourcentage de la cible réelle le modèle a-t-il laissé passer entre les mailles du filet ?"
#
# - Exemple Concret : Un système de détection d'incendies. Un rappel de 99% signifie que le modèle détecte 99 incendies sur 100, mais en manque 1 (Faux Négatif).
#
# - Contexte d'Utilité Majeure : Essentiel lorsque le coût d'un Faux Négatif est intolérable ou dangereux (ex: rater un diagnostic médical grave, manquer une panne de serveur critique).
#
# 4. F1-Score
#
# - Définition : Moyenne harmonique de la Précision et du Rappel..
#
# - Interprétation : Fournit un indicateur unique évaluant le compromis global entre la précision et le rappel. Il pénalise lourdement si l'une des deux métriques est mauvaise.
#
# - Exemple Concret : Si un modèle a une Précision de 99% mais un Rappel de 10%, son F1-Score s'effondre à 18%, révélant l'inefficacité du système.
#
# - Contexte d'Utilité Majeure : C'est la métrique de référence pour évaluer les modèles en production sur des jeux de données déséquilibrés (ex: classification de tickets de pannes rares).
#
# 5. ROC-AUC (Area Under the Receiver Operating Characteristic)
#
# - Définition : Aire sous la courbe représentant le taux de vrais positifs en fonction du taux de faux positifs pour tous les seuils de discrimination possibles.
#
# - Interprétation : Mesure la capacité du modèle à séparer ou classer les éléments (ex: attribuer un score de probabilité plus élevé à un vrai ticket de sécurité qu'à un ticket normal). Un score de 0.5 équivaut au hasard, 1.0 est parfait.
#
# - Exemple Concret : Un ROC-AUC de 0.92 signifie qu'il y a 92% de chances que le modèle classe une véritable anomalie cyber au-dessus d'un comportement utilisateur normal.
#
# - Contexte d'Utilité Majeure : Idéal pour évaluer la performance intrinsèque d'un classifieur indépendamment du choix du seuil de décision final (souvent fixé par défaut à 0.5).

# %% [markdown]
# #### <span style="color: #5498f7">5) Prompt pour l'explication Technique des Métriques de Régression</span>
#
# __Prompt__
#
# TÂCHE : Génère un guide technique expliquant les métriques de régression continue suivantes : MAE, MSE, RMSE.
#
# FORMAT DE SORTIE REQUIS : Pour chaque métrique, structure de manière identique avec : [Définition], [Interprétation], [Exemple Concret], [Contexte d'Utilité Majeure].

# %% [markdown]
# __Réponse générer par le LLM__
#
# 1. MAE (Mean Absolute Error)
#
# - Définition : Moyenne arithmétique de la valeur absolue des écarts entre les prédictions du modèle et les valeurs réelles.
#
# - Interprétation : Donne l'erreur moyenne brute commise par l'IA. Chaque erreur est traitée de manière strictement proportionnelle (linéaire).
#
# - Exemple Concret : Lors de la prédiction de la consommation d'un bâtiment, une MAE de 4.2 kWh signifie qu'en moyenne, l'IA se trompe de \(\pm \) 4.2 kWh par rapport à la consommation constatée.
#
# - Contexte d'Utilité Majeure : À privilégier pour la communication avec les directions métiers, car l'erreur s'exprime de manière transparente dans la même unité de mesure que la cible et n'est pas distordue par des opérations géométriques.
#
# 2. MSE (Mean Squared Error)
#
# - Définition : Moyenne de la somme des carrés des écarts entre prédictions et réalités.
#
# - Interprétation : En élevant les erreurs au carré, cette métrique modifie l'unité de mesure d'origine (ex: elle transforme des kWh en \(kWh^{2}\)), ce qui la rend difficile à lire pour un humain, mais hautement informative pour les mathématiques.
#
# - Exemple Concret : Pour une erreur réelle de 2 kWh, la pénalité statistique est de 4. Pour une erreur de 10 kWh, la pénalité s'envole à 100.
#
# - Contexte d'Utilité Majeure : C'est la fonction de perte préférée des algorithmes pendant leur phase d'optimisation mathématique (descente de gradient) car elle est différentiable en tout point.
#
# 3. RMSE (Root Mean Squared Error)
#
# - Définition : Racine carrée de la Moyenne des Erreurs au Carré (MSE).
#
# - Interprétation : Ramène la MSE à l'unité de mesure d'origine (les kWh) tout en conservant la propriété fondamentale de pénalisation exponentielle des grandes erreurs.
#
# - Exemple Concret : Si le modèle fait de petites erreurs régulières, la RMSE sera proche de la MAE. Si le modèle fait une seule prédiction catastrophique (ex: passer à côté d'un pic de consommation industrielle), la RMSE va exploser par rapport à la MAE.
#
# - Contexte d'Utilité Majeure : Indispensable en production lorsque faire une grosse erreur de prédiction est stratégiquement beaucoup plus préjudiciable ou coûteux pour l'entreprise que de faire une multitude de légères approximations.
